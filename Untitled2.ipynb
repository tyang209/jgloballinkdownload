# %%
from bs4 import BeautifulSoup
import re
import codecs
import requests
import copy
import datetime

# %%
x =datetime.datetime(2015, 2, 27, 16, 22, 49, 821000)
y= datetime.datetime(2015, 2, 27, 16, 35, 6, 571000)

((y-x).seconds)/60
# Out:
# 12

# %%
soup = None
with open('test.html','rb') as f:
    soup = BeautifulSoup(f.read())

# %%
bs = BeautifulSoup(soup.html.body.decode_contents(formatter="html"),'html.parser')

# %%
soup.find('td',{'id':'JD_MAIN'}).findAll('div')
# Out:
# [<div class="withIconCol"><p class="imgL"><img alt="文献" height="16" src="./寶 馨   研究者情報   J-GLOBAL 科学技術総合リンクセンター_files/icon_document.png" width="40"/></p><p class="txtR light"><a class="fwB" href="http://jglobal.jst.go.jp/detail.php?JGLOBAL_ID=200902218217885954&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">平成16年福井豪雨における洪水流量の推定と中小河川流域の治水計画に関する考察</a></p></div>,
#  <div class="withIconCol"><p class="imgL"><img alt="文献" height="16" src="./寶 馨   研究者情報   J-GLOBAL 科学技術総合リンクセンター_files/icon_document.png" width="40"/></p><p class="txtR light"><a class="fwB" href="http://jglobal.jst.go.jp/detail.php?JGLOBAL_ID=200902216973675600&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">水・気象災害軽減のための統合型リアルタイム情報発信基盤の開発</a></p></div>,
# ...

# %%
linkArray = []
books = []
jglobal_id_regex = re.compile(r'.*JGLOBAL_ID=(\d+)')
for div in soup.findAll('div'):
    print 'DIV'
    print div
    print 'div sibling'
    print div.find_next('p')
#     paperDict = {}

#     link = div.find('a')['href']

#     if link in linkArray:
#         continue

#     linkArray.append(link)
#     paperDict['PaperLink'] = link
#     match = jglobal_id_regex.match(link)

#     if match:
#         paperDict['PaperinJGLOBAL'] = 'Yes'
#         paperDict['JGLOBALID'] = match.group(1)   

#     for p in div.findAll('p'):
#         if p['class'] ==['txtR', 'light']:
#             paperDict['Title'] = p.text

#     for span in div.next_sibling.findAll('span',{'class':'fwB'}):
#         translatedKey = translationDict[span.text.replace(u'\uff1a','').strip()]
#         if translatedKey=='Authors':
#             paperDict[translatedKey] = [author.strip() for author in span.next_sibling.split(u'\u3001')]
#         else:
#             paperDict[translatedKey]= span.next_sibling.strip()
#     papers.append(paperDict)
# Out:
# DIV
# <div class="withIconCol">
# <p class="imgL">
# <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
# </p>
# <p class="txtR light">
# <a class="fwB" href="/detail.php?JGLOBAL_ID=201403086216499740&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
#    変速機
#   </a>
# </p>
# </div>
# div sibling
# <p class="imgL">
# <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
# </p>
# DIV
# <div class="withIconCol">
# <p class="imgL">
# <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
# </p>
# <p class="txtR light">
# <a class="fwB" href="/detail.php?JGLOBAL_ID=201403072483248403&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
#    駆動ユニットを備えた機械構造
#   </a>
# </p>
# </div>
# div sibling
# <p class="imgL">
# <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
# </p>
# DIV
# <div class="withIconCol">
# <p class="imgL">
# ...

# %%
patentArray = []
for div in soup.findAll('div'):
    patent = {}
    for p in div.findAll('p'):
        if p['class'] in (['light'],['txtR', 'light']):
            patent['Title'] = p.text
            patent['Link'] = p.find('a')['href']
        
        elif p['class'] in [['light','mB10']]:
            for span in p.findAll('span',{'class':'fwB'}):                
                patent['Inventors']=[inventor.strip() for inventor in span.next_sibling.split(',')]
    patentArray.append(patent)

for index,line in enumerate(patentArray):
    for k,v in line.iteritems():
        print index,k,v
# Out:
# 0 Inventors [u'(\u3044\u305a\u308c\u3082\u5206\u62c5\u8457\u4f5c\u8005)']
# 0 Link /search.php?q=%22%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6%20%E3%83%87%E3%82%B8%E3%82%BF%E3%83%AB%E3%82%B3%E3%83%B3%E3%83%86%E3%83%B3%E3%83%84%20(C006%20%20%20Clinical%20Embryology%E3%80%81C007%20%20Movie%3ADevelopment%20of%20the%20Human%20Embryo%E3%80%81C008%20%20%E3%83%92%E3%83%88%E8%83%8E%E5%85%90%E3%83%A2%E3%83%87%E3%83%AB)%22&t=3
# 0 Title 京都大学 デジタルコンテンツ (C006   Clinical Embryology、C007  Movie:Development of the Human Embryo、C008  ヒト胎児モデル)

# %%
translationDict = {u'\u30da\u30fc\u30b8':'Page',
                   u'\u53f7':'Issue',
                    u'\u5dfb':'Volume',
                    u'\u8cc7\u6599\u540d':'JournalName',
                    u'\u8457\u8005':'Authors',
                    u'\u767a\u884c\u5e74':'PubYear',
					u'\u90e8\u7f72':'Department',
					u'\u4f4f\u6240':'Address',
					u'\u4e8b\u696d\u6982\u8981':'Department_Description',
					u'\u90e8\u7f72\u30fb\u8077\u540d':'Department_Job_Title',
					u'\u7814\u7a76\u8005\u30ea\u30be\u30eb\u30d0\u30fc':'Resolver',
					u'NDL\u30b5\u30fc\u30c1' : 'NDL',
					u'\u7814\u7a76\u8005HP(\u65e5)':'Personal_Home_Page',
					u'\u66f8\u7c4d':'Books',
					u'\u767a\u660e\u8005':'Inventor',
					u'\u51fa\u9858\u4eba/\u7279\u8a31\u6a29\u8005':'Patentee',
					u'\u516c\u5831\u7a2e\u5225':'Patent_Type',
					u'\u51fa\u9858\u756a\u53f7':'Patent_Number',
					u'\u51fa\u9858\u65e5':'Filing_Date',
					u'\u6982\u8981(\u8acb\u6c42\u98051)':'Patent_Summary'
						}

# %%
grantArray = []
if len(soup.findAll('tr'))==0:
    array.soup.text
for row in soup.findAll('tr'):
    grantDict = {}
    if len(row.th.text)>0:
        years = row.th.text.split(' - ')
        if len(years[0])>0:
            grantDict['StartYear']=years[0]
        if len(years[1])>0:
            grantDict['EndYear'] = years[1]
    grantDict['Grant']  = row.td.text
    grantArray.append(grantDict)

for index,line in enumerate(grantArray):
    for k,v in line.iteritems():
        print index,k,v
# Out:
# 0 EndYear 現在
# 0 StartYear 2014年04月
# 0 Grant 東南アジアの社会と文化研究会 世話人
# 1 EndYear 2006年
# 1 StartYear 2006年
# 1 Grant 京都人類学研究会 学生運営委員

# %%
for line in soup.findAll('br'):
    print line.previous_sibling
# Out:
# 地域研究(博士) (京都大学)
# 人間・環境学(修士) (京都大学)

# %%
papers = []
linkArray=[]
jglobal_id_regex = re.compile(r'.*JGLOBAL_ID=(\d+)')
for index,div in enumerate(soup.html.body.td.findAll('div',recursive=False)):

    paperDict = {}

    link = div.find('a')['href']

    if link in linkArray:
        continue
        
    linkArray.append(link)
    paperDict['PaperLink'] = link
    match = jglobal_id_regex.match(link)

    if match:
        paperDict['PaperinJGLOBAL'] = 'Yes'
        paperDict['JGLOBALID'] = match.group(1)   
        
    for p in div.findAll('p'):
        if p['class'] ==['txtR', 'light']:
            paperDict['Title'] = p.text

        
    for span in div.next_sibling.findAll('span',{'class':'fwB'}):
        translatedKey = translationDict[span.text.replace(u'\uff1a','').strip()]
        if translatedKey=='Authors':
            paperDict[translatedKey] = [author.strip() for author in span.next_sibling.split(u'\u3001')]
        else:
            paperDict[translatedKey]= span.next_sibling.strip()
    papers.append(paperDict)
    
for index,line in enumerate(papers):
    for k,v in line.iteritems():
        print index,k,v
# Out:
# 0 Patentee いすゞ自動車株式会社、国立大学法人京都大学
# 0 PaperinJGLOBAL Yes
# 0 Patent_Type 特許公報
# 0 Title 変速機
# 0 Patent_Number 特願2009-027239
# 0 JGLOBALID 201403086216499740
# 0 Patent_Summary 【請求項1】  回転可能に支持された入力軸と出力軸との間にそれぞれ配置された、少なくとも2組の歯車要素対である第1の歯車要素対及び第2の歯車要素対と、
#   前記入力軸と前記出力軸との間に、少なくとも2・・・
# 0 Filing_Date 2009年02月09日
# 0 PaperLink /detail.php?JGLOBAL_ID=201403086216499740&q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&t=1
# 0 Inventor 古賀  英隆、小森  雅晴
# 1 Patentee 国立大学法人京都大学
# 1 PaperinJGLOBAL Yes
# 1 Patent_Type 特許公報
# 1 Title 駆動ユニットを備えた機械構造
# 1 Patent_Number 特願2010-032989
# 1 JGLOBALID 201403072483248403
# 1 Patent_Summary 【請求項1】  基礎部材と、前記基礎部材に固定された1つの案内部及び該案内部に固定された1つの仮想線に沿って受動移動が可能である可動部を含む、少なくとも1つの支持部材とを有する移動体と、
#   前記基礎・・・
# 1 Filing_Date 2010年02月17日
# 1 PaperLink /detail.php?JGLOBAL_ID=201403072483248403&q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&t=1
# 1 Inventor 小森  雅晴、松田  吉平
# 2 Patentee 国立大学法人京都大学、いすゞ自動車株式会社
# 2 PaperinJGLOBAL Yes
# 2 Patent_Type 特許公報
# 2 Title 非円形歯車要素対を用いた変速機
# ...

# %%
print u'\u6982\u8981(\u8acb\u6c42\u98051)'
# Out:
# 概要(請求項1)

# %%
r = requests.get("http://jglobal.jst.go.jp/detail.php?JGLOBAL_ID=200901069127676630&q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&t=1&e=PR&p=2")

# %%
html = """<html>
 <body>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201403086216499740&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 いすゞ自動車株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 古賀  英隆、小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2009-027239
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2009年02月09日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  回転可能に支持された入力軸と出力軸との間にそれぞれ配置された、少なくとも2組の歯車要素対である第1の歯車要素対及び第2の歯車要素対と、
  前記入力軸と前記出力軸との間に、少なくとも2・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201403072483248403&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   駆動ユニットを備えた機械構造
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、松田  吉平
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-032989
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年02月17日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  基礎部材と、前記基礎部材に固定された1つの案内部及び該案内部に固定された1つの仮想線に沿って受動移動が可能である可動部を含む、少なくとも1つの支持部材とを有する移動体と、
  前記基礎・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201403070721628144&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   非円形歯車要素対を用いた変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学、いすゞ自動車株式会社
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、古賀  英隆
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-111549
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年05月13日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  回転可能に支持された第1組の入力部材及び出力部材と、
  前記第1組の入力部材と出力部材の間にそれぞれ配置された、少なくとも2組の歯車要素対と、
  前記第1組の入力部材と出力部材の間・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201403044637071109&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   駆動装置
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 三菱電機株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、大賀  荘平、野田  哲男、奥田  晴久、田中  健一
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2009-259681
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2009年11月13日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】(a) 1自由度運動を生成する第1アクチュエータと、
(b) 上記第1アクチュエータの駆動を制御する第1アクチュエータ制御部と、
(c) 上記第1アクチュエータで生成される1自由度運動に基・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201403024159857168&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   非円形歯車対を用いた変速機の変速方法
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学、いすゞ自動車株式会社
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、古賀  英隆
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-282040
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年12月17日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  回転可能に支持された入力部材と、
  回転可能に支持された出力部材と、
  前記入力部材と前記出力部材との間にそれぞれ配置され、前記入力部材と前記出力部材との間に連結されたときの減速比・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201303087971690573&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   移動搬送機構
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2008-018089
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2008年01月29日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  ホイール回転中心軸を中心に回転自在に支持される少なくとも1つのホイール部材と、
  前記ホイール回転中心軸を中心とする円周に沿ってそれぞれの副車輪回転中心軸が延在し、前記ホイール部材に・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201303050710061055&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   駆動ユニット
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2012-039454
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2012年02月26日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】歯車装置にアクチュエータを組み込んでも剛性を高くすることができる駆動ユニットを提供する。【解決手段】第1、第2の内歯車22,24が間隔を設けて同軸に形成された第1の歯車部材20と、第1、第2の・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201303045225537560&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 いすゞ自動車株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 古賀  英隆、小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2009-027240
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2009年02月09日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  回転可能に支持された入力軸と出力軸との間にそれぞれ配置された、第1の歯車要素対及び第2の歯車要素対と、
  前記入力軸と前記出力軸との間に、前記第1の歯車要素対及び前記第2の歯車要素対・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201203074912986718&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   非円形歯車対を備えた変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学、いすゞ自動車株式会社
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、古賀  英隆
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2011-021725
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2011年02月03日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】変速機本体にかかるトルクを抑制できる非円形歯車対を備えた変速機を提供する。【解決手段】変速機本体10は、入力部材と出力部材との間に、複数の歯車対と非円形歯車対とがクラッチを介して選択的に連結さ・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201203064925063826&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   産業用ロボットシステム
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 三菱電機株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 野田  哲男、奥田  晴久、田中  健一、椹木  哲夫、松久  寛・・・
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 再公表公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 JP2010051962
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年02月10日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 課題:据付調整時間の短縮、運用開始後のエラー無し連続操業時間の拡大が可能な産業用ロボットシステムを得る。解決手段:チョコ停対応行動計画部(4)と、エラー誘発作業抑制部(5)と、教示作業部(6)と、動作・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201203056426565117&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   非円形歯車対を用いた変速機の変速方法
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学、いすゞ自動車株式会社
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、古賀  英隆
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-282040
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年12月17日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】クラッチや歯車の設計の自由度を高くでき、最適な性能となるクラッチや歯車を備えた変速機を実現しやすい、非円形歯車対を用いた変速機の変速方法を提供する。【解決手段】入力部材12と出力部材14との間・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201203020904845932&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   非円形歯車対を備えた変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学、いすゞ自動車株式会社
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、古賀  英隆
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-282036
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年12月17日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】一つの非円形歯車対をアップシフトとダウンシフトの両方に用いることができる変速機を提供する。【解決手段】入力部材と出力部材との間に、クラッチを介して、少なくとも3つの第1段乃至第3段の歯車対と、・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201103081717194296&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   駆動装置
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 三菱電機株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、大賀  荘平、野田  哲男、奥田  晴久、田中  健一
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2009-259681
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2009年11月13日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】特性が異なる2つのアクチュエータを組み合わせたハイブリッド型の駆動装置を提供する。【解決手段】駆動装置は、直線運動を生成するエアシリンダと、エアシリンダの駆動を制御するエアシリンダ制御部と、エ・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201103068345303836&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   非円形歯車要素対を用いた変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学、いすゞ自動車株式会社
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、古賀  英隆
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-111549
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年05月13日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】減速比の様々な組み合わせに対して非円形歯車対の減速比の変化を円滑にすることができ、正確に回転角度を伝達し、かつ動力を効率的に伝達することができる変速機を提供する。【解決手段】歯車要素対16,1・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201103060442889380&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   駆動ユニットを備えた機械構造
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、松田  吉平
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2010-032989
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2010年02月17日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】広い移動領域を得られ、駆動源を有効に利用しやすい、駆動ユニットを備えた機械構造を提供する。【解決手段】少なくとも3つの駆動ユニット50x,52x,54xが、基準面に沿って1方向又は2方向に能動・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201103040034190564&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   歯車歯面形状測定機の評価法
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 独立行政法人産業技術総合研究所
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、久保  愛三、近藤  孝之、高辻  利之、直井  一也・・・
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 特許公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2005-126692
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2005年04月25日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【請求項1】  歯車歯面形状測定機のはすば歯車歯筋測定に対する検査・校正に用いる検査・校正アーティファクトであって、
検査・校正アーティファクトは斜面、背面の各平面を有するとともに、右側面、左側面、上・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201003096042880608&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 いすゞ自動車株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 古賀  英隆、小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2009-027239
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2009年02月09日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】短時間で噛み合いのON/OFF作業を終えることができ、過大なトルクがかかった場合にクラッチが切れて変速機の破壊を防止する。【解決手段】回転可能に支持された入力軸12と出力軸14との間にそれぞれ・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201003090191004618&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   変速機
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 いすゞ自動車株式会社、国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 古賀  英隆、小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2009-027240
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2009年02月09日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】減速機構及び増速機構の占有スペースを低減することができ、自動車の変速機として採用できる変速機を提供する。【解決手段】2組の歯車要素対と、入力軸と出力軸と2組の歯車要素対を解除可能に連結する2組・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=201003014623297753&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   変速機及び変速方法
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 再公表公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 JP2007072215
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2007年11月15日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 回転を止めることなく負荷を支持しつつ減速比を変えることができ、正確に回転角度を伝達し、かつ動力を効率的に伝達することができる変速機及び変速方法を提供する。  入力部材12と出力部材14との間に、第1及・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=200903078260723787&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   移動搬送機構
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2008-018089
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2008年01月29日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】簡単な構成で主車輪の回転駆動と副車輪の回転駆動とを行うことができる移動搬送機構を提供する。【解決手段】ホイール回転中心軸20sを中心に回転自在に支持されるホイール部材20に、少なくとも1つの副・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=200903064651496709&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   歯車歯面形状測定機の評価法
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 独立行政法人産業技術総合研究所
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、久保  愛三、近藤  孝之、高辻  利之、直井  一也・・・
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2005-126692
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2005年04月25日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】  (1)高精度に製作でき、(2)高精度に値付け測定ができ、(3)トレーサビリティの保証も容易に行える、はすば歯車歯筋測定に対する検査・校正に用いる検査・校正アーティファクト及び検査・校正法を・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=200903046521525830&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   形状測定機の検査・校正アーティファクト
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、久保  愛三
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2004-369454
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2004年12月21日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】  形状測定機が被測定物の被測定面の形状周波数成分をどの程度正しく測定することができるかを検査・校正することができ、複数個の同じ形状のものを高精度に作製することができ、値付けや検査・校正の際の・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=200903016670383325&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   歯車歯面形状測定機の検査・校正アーティファクト
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、久保  愛三
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 公開公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 特願2004-360216
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2004年12月13日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 【課題】  1)高精度な形状測定機で容易に、トレーサブルな値付け測定をすることができ、2)歯車歯面形状測定機の検査・校正を短時間で容易に、正確に、かつトレーサブルに行うことができ、3)歯車歯面の精度規・・・
</p>
<div class="withIconCol">
 <p class="imgL">
  <img alt="特許" height="16" src="/common/images/icon/icon_patent.png" width="40"/>
 </p>
 <p class="txtR light">
  <a class="fwB" href="/detail.php?JGLOBAL_ID=200903014047582721&amp;q=%E4%BA%AC%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">
   歯車の歯やねじのピッチの非接触測定法
  </a>
 </p>
</div>
<p class="light mB10">
 <span class="fwB">
  出願人/特許権者：
 </span>
 国立大学法人京都大学
 <br/>
 <span class="fwB">
  発明者：
 </span>
 小森  雅晴、久保  愛三、織田  祥宏
 <br/>
 <span class="fwB">
  公報種別：
 </span>
 再公表公報
 <span class="mR10">
 </span>
 <span class="fwB">
  出願番号：
 </span>
 JP2005016289
 <span class="mR10">
 </span>
 <span class="fwB">
  出願日：
 </span>
 2005年09月06日
 <br/>
 <span class="fwB">
  概要(請求項1)：
 </span>
 簡易な装置を用いて非接触で短時間に高精度な測定が可能であるピッチ測定方法等を提供する。  ピッチ測定方法は、略同一形状の複数の注目形状部4を有する対象物2について、注目形状部4が同一の経路8上を移動す・・・
</p>
 </body>
</html>"""

# %%
papers = []
linkArray = []
jglobal_id_regex = re.compile(r'.*JGLOBAL_ID=(\d+)')
for div in soup.findAll('div'):
    print div.find('a')
    paperDict = {}

    link = div.find('a')['href']

    if link in linkArray:
        continue

    linkArray.append(link)
    paperDict['PaperLink'] = link
    match = jglobal_id_regex.match(link)

    if match:
        paperDict['PaperinJGLOBAL'] = 'Yes'
        paperDict['JGLOBALID'] = match.group(1)   

    for p in div.findAll('p'):
        if p['class'] ==['txtR', 'light']:
            paperDict['Title'] = p.text

    for span in div.next_sibling.findAll('span',{'class':'fwB'}):
        paperDict[span.text] = span.next_sibling.strip()

    papers.append(paperDict)
    print paperDict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-322-2bd20f161b33> in <module>()
#      24
#      25     for span in div.next_sibling.findAll('span',{'class':'fwB'}):
# ---> 26         paperDict[span.text] = span.next_sibling.strip()
#      27
#      28     papers.append(paperDict)
#
# AttributeError: 'NoneType' object has no attribute 'strip'
# <a class="fwB" href="/detail.php?JGLOBAL_ID=201403086216499740&amp;q=%E4%BA%A
# C%E9%83%BD%E5%A4%A7%E5%AD%A6&amp;t=1">σñëΘÇƒµ⌐ƒ</a>
# ...

# %%
print u'\u03c3\xe7\u2551\u0398\xed\xff\u03a3\u2551\u2551/\u03c4\xeb\u2563\u03a6\xbf\u2592\xb5\xbf\u2310\u03a6\xc7\xe0\u2229\u255d\xdc'
# Out:
# σç║ΘíÿΣ║║/τë╣Φ¿▒µ¿⌐ΦÇà∩╝Ü

# %%
for div in masterSoup.findAll('div'):
    print div.next_sibling
